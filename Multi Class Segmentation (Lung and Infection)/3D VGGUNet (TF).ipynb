# %%
import zipfile
import os
import os.path 
import nibabel as nib
import numpy as np
import pandas as pd
import shutil
import random
import re

# %%
path1 = '/content/drive/MyDrive/3D Segmentation/data used/lim 128'

dpath = '/content/data used'

for i in os.listdir(path1):
  print(i)
  file = i.split('.zip')
  filename = file[0]
  zip_file=zipfile.ZipFile(path1 + '/' + i)
  zip_file.extractall(dpath + '/' + str(filename) + '/' )
# Out:
# lim 128.zip
# ctscan 128.zip

# %%
ct = []
lim = []

for i in os.listdir(dpath):
  a = dpath + '/' + i
  if os.path.isdir(a):
    for i in os.listdir(a):
      filepath = a + '/' + i
      if 'ctscan' in filepath:
        ct.append(filepath)
      elif 'lim' in filepath:
        lim.append(filepath)

# %%
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(data, key=alphanum_key)

# %%
ct = sorted_alphanumeric(ct)
lim = sorted_alphanumeric(lim)

# %%
print(ct)
print(lim)
# Out:
# ['/content/data used/ctscan 128/coronacases_001.nii.nii.gz', '/content/data used/ctscan 128/coronacases_002.nii.nii.gz', '/content/data used/ctscan 128/coronacases_003.nii.nii.gz', '/content/data used/ctscan 128/coronacases_004.nii.nii.gz', '/content/data used/ctscan 128/coronacases_005.nii.nii.gz', '/content/data used/ctscan 128/coronacases_006.nii.nii.gz', '/content/data used/ctscan 128/coronacases_007.nii.nii.gz', '/content/data used/ctscan 128/coronacases_008.nii.nii.gz', '/content/data used/ctscan 128/coronacases_009.nii.nii.gz', '/content/data used/ctscan 128/coronacases_010.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_4_85506_1.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_7_85703_0.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_10_85902_1.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_10_85902_3.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_14_85914_0.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_27_86410_0.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_29_86490_1.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_29_86491_1.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_36_86526_0.nii.nii.gz', '/content/data used/ctscan 128/radiopaedia_40_86625_0.nii.nii.gz']
# ['/content/data used/lim 128/coronacases_001.nii.nii.gz', '/content/data used/lim 128/coronacases_002.nii.nii.gz', '/content/data used/lim 128/coronacases_003.nii.nii.gz', '/content/data used/lim 128/coronacases_004.nii.nii.gz', '/content/data used/lim 128/coronacases_005.nii.nii.gz', '/content/data used/lim 128/coronacases_006.nii.nii.gz', '/content/data used/lim 128/coronacases_007.nii.nii.gz', '/content/data used/lim 128/coronacases_008.nii.nii.gz', '/content/data used/lim 128/coronacases_009.nii.nii.gz', '/content/data used/lim 128/coronacases_010.nii.nii.gz', '/content/data used/lim 128/radiopaedia_4_85506_1.nii.nii.gz', '/content/data used/lim 128/radiopaedia_7_85703_0.nii.nii.gz', '/content/data used/lim 128/radiopaedia_10_85902_1.nii.nii.gz', '/content/data used/lim 128/radiopaedia_10_85902_3.nii.nii.gz', '/content/data used/lim 128/radiopaedia_14_85914_0.nii.nii.gz', '/content/data used/lim 128/radiopaedia_27_86410_0.nii.nii.gz', '/content/data used/lim 128/radiopaedia_29_86490_1.nii.nii.gz', '/content/data used/lim 128/radiopaedia_29_86491_1.nii.nii.gz', '/content/data used/lim 128/radiopaedia_36_86526_0.nii.nii.gz', '/content/data used/lim 128/radiopaedia_40_86625_0.nii.nii.gz']

# %%
len(ct), len(lim)
# Out:
# (20, 20)

# %%
data = pd.DataFrame({'CT File':ct, 'LIM':lim})

# %%
data
# Out:
#                                               CT File  \
# 0   /content/data used/ctscan 128/coronacases_001....
# 1   /content/data used/ctscan 128/coronacases_002....
# 2   /content/data used/ctscan 128/coronacases_003....
# 3   /content/data used/ctscan 128/coronacases_004....
# 4   /content/data used/ctscan 128/coronacases_005....
# 5   /content/data used/ctscan 128/coronacases_006....
# 6   /content/data used/ctscan 128/coronacases_007....
# 7   /content/data used/ctscan 128/coronacases_008....
# 8   /content/data used/ctscan 128/coronacases_009....
# 9   /content/data used/ctscan 128/coronacases_010....
# 10  /content/data used/ctscan 128/radiopaedia_4_85...
# 11  /content/data used/ctscan 128/radiopaedia_7_85...
# 12  /content/data used/ctscan 128/radiopaedia_10_8...
# 13  /content/data used/ctscan 128/radiopaedia_10_8...
# 14  /content/data used/ctscan 128/radiopaedia_14_8...
# 15  /content/data used/ctscan 128/radiopaedia_27_8...
# 16  /content/data used/ctscan 128/radiopaedia_29_8...
# 17  /content/data used/ctscan 128/radiopaedia_29_8...
# 18  /content/data used/ctscan 128/radiopaedia_36_8...
# 19  /content/data used/ctscan 128/radiopaedia_40_8...
#
#                                                   LIM
# 0   /content/data used/lim 128/coronacases_001.nii...
# 1   /content/data used/lim 128/coronacases_002.nii...
# 2   /content/data used/lim 128/coronacases_003.nii...
# 3   /content/data used/lim 128/coronacases_004.nii...
# 4   /content/data used/lim 128/coronacases_005.nii...
# 5   /content/data used/lim 128/coronacases_006.nii...
# 6   /content/data used/lim 128/coronacases_007.nii...
# 7   /content/data used/lim 128/coronacases_008.nii...
# 8   /content/data used/lim 128/coronacases_009.nii...
# 9   /content/data used/lim 128/coronacases_010.nii...
# 10  /content/data used/lim 128/radiopaedia_4_85506...
# 11  /content/data used/lim 128/radiopaedia_7_85703...
# 12  /content/data used/lim 128/radiopaedia_10_8590...
# 13  /content/data used/lim 128/radiopaedia_10_8590...
# 14  /content/data used/lim 128/radiopaedia_14_8591...
# 15  /content/data used/lim 128/radiopaedia_27_8641...
# 16  /content/data used/lim 128/radiopaedia_29_8649...
# 17  /content/data used/lim 128/radiopaedia_29_8649...
# 18  /content/data used/lim 128/radiopaedia_36_8652...
# 19  /content/data used/lim 128/radiopaedia_40_8662...

# %%
randomn = random.randint(0, len(ct))

a = ct[randomn].split('/')
b = lim[randomn].split('/')

print(a[-1])
print(b[-1])
# Out:
# radiopaedia_36_86526_0.nii.nii.gz
# radiopaedia_36_86526_0.nii.nii.gz

# %%
path = os.chdir('/content/data used/ctscan 128')
filename = os.listdir(path)

for file in filename:
    new = "CT_{}.nii.gz".format(file[:-11])
    print("renaming: \n {}".format(file))
    print("\n into: \n {}\n".format(new))
    os.rename(file, new)
# Out:
# renaming:
#  coronacases_007.nii.nii.gz
#
#  into:
#  CT_coronacases_007.nii.gz
#
# renaming:
#  coronacases_009.nii.nii.gz
#
#  into:
#  CT_coronacases_009.nii.gz
#
# renaming:
#  coronacases_002.nii.nii.gz
#
#  into:
#  CT_coronacases_002.nii.gz
#
# renaming:
#  coronacases_006.nii.nii.gz
#
#  into:
#  CT_coronacases_006.nii.gz
#
# renaming:
#  coronacases_010.nii.nii.gz
#
#  into:
#  CT_coronacases_010.nii.gz
#
# renaming:
#  coronacases_004.nii.nii.gz
#
#  into:
#  CT_coronacases_004.nii.gz
#
# renaming:
#  radiopaedia_7_85703_0.nii.nii.gz
#
#  into:
#  CT_radiopaedia_7_85703_0.nii.gz
#
# renaming:
#  radiopaedia_10_85902_1.nii.nii.gz
#
#  into:
#  CT_radiopaedia_10_85902_1.nii.gz
#
# renaming:
#  radiopaedia_36_86526_0.nii.nii.gz
#
#  into:
#  CT_radiopaedia_36_86526_0.nii.gz
#
# renaming:
#  radiopaedia_4_85506_1.nii.nii.gz
#
#  into:
#  CT_radiopaedia_4_85506_1.nii.gz
#
# renaming:
#  coronacases_005.nii.nii.gz
#
#  into:
#  CT_coronacases_005.nii.gz
#
# renaming:
#  radiopaedia_10_85902_3.nii.nii.gz
#
#  into:
#  CT_radiopaedia_10_85902_3.nii.gz
#
# renaming:
#  radiopaedia_29_86490_1.nii.nii.gz
#
#  into:
#  CT_radiopaedia_29_86490_1.nii.gz
#
# renaming:
#  coronacases_008.nii.nii.gz
#
#  into:
#  CT_coronacases_008.nii.gz
#
# renaming:
#  radiopaedia_27_86410_0.nii.nii.gz
#
#  into:
#  CT_radiopaedia_27_86410_0.nii.gz
#
# renaming:
#  radiopaedia_14_85914_0.nii.nii.gz
#
#  into:
#  CT_radiopaedia_14_85914_0.nii.gz
#
# renaming:
#  coronacases_001.nii.nii.gz
#
#  into:
#  CT_coronacases_001.nii.gz
#
# renaming:
#  radiopaedia_40_86625_0.nii.nii.gz
#
#  into:
#  CT_radiopaedia_40_86625_0.nii.gz
#
# renaming:
#  radiopaedia_29_86491_1.nii.nii.gz
#
#  into:
#  CT_radiopaedia_29_86491_1.nii.gz
#
# renaming:
#  coronacases_003.nii.nii.gz
#
#  into:
#  CT_coronacases_003.nii.gz

# %%
path = os.chdir('/content/data used/lim 128')
filename = os.listdir(path)

for file in filename:
    new = "LIM_{}.nii.gz".format(file[:-11])
    print("renaming: \n {}".format(file))
    print("\n into: \n {}\n".format(new))
    os.rename(file, new)
# Out:
# renaming:
#  coronacases_007.nii.nii.gz
#
#  into:
#  LIM_coronacases_007.nii.gz
#
# renaming:
#  coronacases_009.nii.nii.gz
#
#  into:
#  LIM_coronacases_009.nii.gz
#
# renaming:
#  coronacases_002.nii.nii.gz
#
#  into:
#  LIM_coronacases_002.nii.gz
#
# renaming:
#  coronacases_006.nii.nii.gz
#
#  into:
#  LIM_coronacases_006.nii.gz
#
# renaming:
#  coronacases_010.nii.nii.gz
#
#  into:
#  LIM_coronacases_010.nii.gz
#
# renaming:
#  coronacases_004.nii.nii.gz
#
#  into:
#  LIM_coronacases_004.nii.gz
#
# renaming:
#  radiopaedia_7_85703_0.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_7_85703_0.nii.gz
#
# renaming:
#  radiopaedia_10_85902_1.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_10_85902_1.nii.gz
#
# renaming:
#  radiopaedia_36_86526_0.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_36_86526_0.nii.gz
#
# renaming:
#  radiopaedia_4_85506_1.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_4_85506_1.nii.gz
#
# renaming:
#  coronacases_005.nii.nii.gz
#
#  into:
#  LIM_coronacases_005.nii.gz
#
# renaming:
#  radiopaedia_10_85902_3.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_10_85902_3.nii.gz
#
# renaming:
#  radiopaedia_29_86490_1.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_29_86490_1.nii.gz
#
# renaming:
#  coronacases_008.nii.nii.gz
#
#  into:
#  LIM_coronacases_008.nii.gz
#
# renaming:
#  radiopaedia_27_86410_0.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_27_86410_0.nii.gz
#
# renaming:
#  radiopaedia_14_85914_0.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_14_85914_0.nii.gz
#
# renaming:
#  coronacases_001.nii.nii.gz
#
#  into:
#  LIM_coronacases_001.nii.gz
#
# renaming:
#  radiopaedia_40_86625_0.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_40_86625_0.nii.gz
#
# renaming:
#  radiopaedia_29_86491_1.nii.nii.gz
#
#  into:
#  LIM_radiopaedia_29_86491_1.nii.gz
#
# renaming:
#  coronacases_003.nii.nii.gz
#
#  into:
#  LIM_coronacases_003.nii.gz

# %%
for i in range(1,21):
  dir = str(i)
  os.makedirs('/content'+'/data tidied/'+dir)

# %%
length = len(os.listdir('/content/data used/ctscan 128'))

path = '/content/data used'

element = -1
for i in range(1,length + 1): 

  element += 1

  for i in sorted_alphanumeric(os.listdir(path)):
    a = path + '/' + i
    print(a)
    
    
    if os.path.isdir(a):
      b = sorted_alphanumeric(os.listdir(a))
      print(element)
      print(b)
      r1 = b[element]

      source = a + '/' + r1
      target = '/content/data tidied/{}/{}'.format(element+1,r1)

      print(source)
      print(target)

      shutil.copy(source, target)
      print(element)
# Out:
# /content/data used/ctscan 128
# 0
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_001.nii.gz
# /content/data tidied/1/CT_coronacases_001.nii.gz
# 0
# /content/data used/lim 128
# 0
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_001.nii.gz
# /content/data tidied/1/LIM_coronacases_001.nii.gz
# 0
# /content/data used/ctscan 128
# 1
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_002.nii.gz
# /content/data tidied/2/CT_coronacases_002.nii.gz
# 1
# /content/data used/lim 128
# 1
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_002.nii.gz
# /content/data tidied/2/LIM_coronacases_002.nii.gz
# 1
# /content/data used/ctscan 128
# 2
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_003.nii.gz
# /content/data tidied/3/CT_coronacases_003.nii.gz
# 2
# /content/data used/lim 128
# 2
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_003.nii.gz
# /content/data tidied/3/LIM_coronacases_003.nii.gz
# 2
# /content/data used/ctscan 128
# 3
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_004.nii.gz
# /content/data tidied/4/CT_coronacases_004.nii.gz
# 3
# /content/data used/lim 128
# 3
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_004.nii.gz
# /content/data tidied/4/LIM_coronacases_004.nii.gz
# 3
# /content/data used/ctscan 128
# 4
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_005.nii.gz
# /content/data tidied/5/CT_coronacases_005.nii.gz
# 4
# /content/data used/lim 128
# 4
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_005.nii.gz
# /content/data tidied/5/LIM_coronacases_005.nii.gz
# 4
# /content/data used/ctscan 128
# 5
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_006.nii.gz
# /content/data tidied/6/CT_coronacases_006.nii.gz
# 5
# /content/data used/lim 128
# 5
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_006.nii.gz
# /content/data tidied/6/LIM_coronacases_006.nii.gz
# 5
# /content/data used/ctscan 128
# 6
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_007.nii.gz
# /content/data tidied/7/CT_coronacases_007.nii.gz
# 6
# /content/data used/lim 128
# 6
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_007.nii.gz
# /content/data tidied/7/LIM_coronacases_007.nii.gz
# 6
# /content/data used/ctscan 128
# 7
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_008.nii.gz
# /content/data tidied/8/CT_coronacases_008.nii.gz
# 7
# /content/data used/lim 128
# 7
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_008.nii.gz
# /content/data tidied/8/LIM_coronacases_008.nii.gz
# 7
# /content/data used/ctscan 128
# 8
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_009.nii.gz
# /content/data tidied/9/CT_coronacases_009.nii.gz
# 8
# /content/data used/lim 128
# 8
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_009.nii.gz
# /content/data tidied/9/LIM_coronacases_009.nii.gz
# 8
# /content/data used/ctscan 128
# 9
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_coronacases_010.nii.gz
# /content/data tidied/10/CT_coronacases_010.nii.gz
# 9
# /content/data used/lim 128
# 9
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_coronacases_010.nii.gz
# /content/data tidied/10/LIM_coronacases_010.nii.gz
# 9
# /content/data used/ctscan 128
# 10
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_4_85506_1.nii.gz
# /content/data tidied/11/CT_radiopaedia_4_85506_1.nii.gz
# 10
# /content/data used/lim 128
# 10
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_4_85506_1.nii.gz
# /content/data tidied/11/LIM_radiopaedia_4_85506_1.nii.gz
# 10
# /content/data used/ctscan 128
# 11
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_7_85703_0.nii.gz
# /content/data tidied/12/CT_radiopaedia_7_85703_0.nii.gz
# 11
# /content/data used/lim 128
# 11
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_7_85703_0.nii.gz
# /content/data tidied/12/LIM_radiopaedia_7_85703_0.nii.gz
# 11
# /content/data used/ctscan 128
# 12
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_10_85902_1.nii.gz
# /content/data tidied/13/CT_radiopaedia_10_85902_1.nii.gz
# 12
# /content/data used/lim 128
# 12
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_10_85902_1.nii.gz
# /content/data tidied/13/LIM_radiopaedia_10_85902_1.nii.gz
# 12
# /content/data used/ctscan 128
# 13
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_10_85902_3.nii.gz
# /content/data tidied/14/CT_radiopaedia_10_85902_3.nii.gz
# 13
# /content/data used/lim 128
# 13
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_10_85902_3.nii.gz
# /content/data tidied/14/LIM_radiopaedia_10_85902_3.nii.gz
# 13
# /content/data used/ctscan 128
# 14
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_14_85914_0.nii.gz
# /content/data tidied/15/CT_radiopaedia_14_85914_0.nii.gz
# 14
# /content/data used/lim 128
# 14
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_14_85914_0.nii.gz
# /content/data tidied/15/LIM_radiopaedia_14_85914_0.nii.gz
# 14
# /content/data used/ctscan 128
# 15
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_27_86410_0.nii.gz
# /content/data tidied/16/CT_radiopaedia_27_86410_0.nii.gz
# 15
# /content/data used/lim 128
# 15
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_27_86410_0.nii.gz
# /content/data tidied/16/LIM_radiopaedia_27_86410_0.nii.gz
# 15
# /content/data used/ctscan 128
# 16
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_29_86490_1.nii.gz
# /content/data tidied/17/CT_radiopaedia_29_86490_1.nii.gz
# 16
# /content/data used/lim 128
# 16
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_29_86490_1.nii.gz
# /content/data tidied/17/LIM_radiopaedia_29_86490_1.nii.gz
# 16
# /content/data used/ctscan 128
# 17
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_29_86491_1.nii.gz
# /content/data tidied/18/CT_radiopaedia_29_86491_1.nii.gz
# 17
# /content/data used/lim 128
# 17
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_29_86491_1.nii.gz
# /content/data tidied/18/LIM_radiopaedia_29_86491_1.nii.gz
# 17
# /content/data used/ctscan 128
# 18
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_36_86526_0.nii.gz
# /content/data tidied/19/CT_radiopaedia_36_86526_0.nii.gz
# 18
# /content/data used/lim 128
# 18
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_36_86526_0.nii.gz
# /content/data tidied/19/LIM_radiopaedia_36_86526_0.nii.gz
# 18
# /content/data used/ctscan 128
# 19
# ['CT_coronacases_001.nii.gz', 'CT_coronacases_002.nii.gz', 'CT_coronacases_003.nii.gz', 'CT_coronacases_004.nii.gz', 'CT_coronacases_005.nii.gz', 'CT_coronacases_006.nii.gz', 'CT_coronacases_007.nii.gz', 'CT_coronacases_008.nii.gz', 'CT_coronacases_009.nii.gz', 'CT_coronacases_010.nii.gz', 'CT_radiopaedia_4_85506_1.nii.gz', 'CT_radiopaedia_7_85703_0.nii.gz', 'CT_radiopaedia_10_85902_1.nii.gz', 'CT_radiopaedia_10_85902_3.nii.gz', 'CT_radiopaedia_14_85914_0.nii.gz', 'CT_radiopaedia_27_86410_0.nii.gz', 'CT_radiopaedia_29_86490_1.nii.gz', 'CT_radiopaedia_29_86491_1.nii.gz', 'CT_radiopaedia_36_86526_0.nii.gz', 'CT_radiopaedia_40_86625_0.nii.gz']
# /content/data used/ctscan 128/CT_radiopaedia_40_86625_0.nii.gz
# /content/data tidied/20/CT_radiopaedia_40_86625_0.nii.gz
# 19
# /content/data used/lim 128
# 19
# ['LIM_coronacases_001.nii.gz', 'LIM_coronacases_002.nii.gz', 'LIM_coronacases_003.nii.gz', 'LIM_coronacases_004.nii.gz', 'LIM_coronacases_005.nii.gz', 'LIM_coronacases_006.nii.gz', 'LIM_coronacases_007.nii.gz', 'LIM_coronacases_008.nii.gz', 'LIM_coronacases_009.nii.gz', 'LIM_coronacases_010.nii.gz', 'LIM_radiopaedia_4_85506_1.nii.gz', 'LIM_radiopaedia_7_85703_0.nii.gz', 'LIM_radiopaedia_10_85902_1.nii.gz', 'LIM_radiopaedia_10_85902_3.nii.gz', 'LIM_radiopaedia_14_85914_0.nii.gz', 'LIM_radiopaedia_27_86410_0.nii.gz', 'LIM_radiopaedia_29_86490_1.nii.gz', 'LIM_radiopaedia_29_86491_1.nii.gz', 'LIM_radiopaedia_36_86526_0.nii.gz', 'LIM_radiopaedia_40_86625_0.nii.gz']
# /content/data used/lim 128/LIM_radiopaedia_40_86625_0.nii.gz
# /content/data tidied/20/LIM_radiopaedia_40_86625_0.nii.gz
# 19

# %%
import nibabel as nib
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import random
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
import glob
import tifffile as tiff
from tifffile import imsave
from PIL import Image
import tensorflow as tf
import cv2 as cv
from PIL import Image
import random

# %%
def applyClahe(img):
    clahe = cv.createCLAHE(clipLimit=3.0)
    claheImage = clahe.apply(np.uint8(img*255))
    return claheImage

# %%
ctimg_sample = nib.load("/content/data tidied/1/CT_coronacases_001.nii.gz").get_fdata()
print('Before Scaling')
print('shape of the image : {}'.format(np.shape(ctimg_sample)))
print('maximum pixel value: {}'.format(ctimg_sample.max()))
print('minimum pixel value: {}'.format(ctimg_sample.min()))

#scaling
scaler = MinMaxScaler()
ctimg_sample2 = scaler.fit_transform(ctimg_sample.reshape(-1, ctimg_sample.shape[-1]))
ctimg_sample2 = applyClahe(ctimg_sample2)
ctimg_sample = scaler.fit_transform(ctimg_sample2.reshape(-1, ctimg_sample2.shape[-1])).reshape(ctimg_sample.shape)
ctimg_sample = ctimg_sample[:,:,:,0]
ctimg_sample = np.stack((ctimg_sample,)*3, axis = -1)

print('\nAfter Scaling')
print('shape of the image : {}'.format(np.shape(ctimg_sample)))
print('maximum pixel value: {}'.format(ctimg_sample.max()))
print('minimum pixel value: {}'.format(ctimg_sample.min()))
# Out:
# Before Scaling
# shape of the image : (128, 128, 128, 1)
# maximum pixel value: 1358.0
# minimum pixel value: -1018.0
#
# After Scaling
# shape of the image : (128, 128, 128, 3)
# maximum pixel value: 1.0
# minimum pixel value: 0.0

# %%
lim_sample = nib.load("/content/data tidied/1/LIM_coronacases_001.nii.gz").get_fdata()

print('original mask value : {}'.format(np.unique(lim_sample))) #ini value nya floating number

#ganti ke int8
lim_sample = lim_sample.astype(np.uint8)
print('converted mask value: {}'.format(np.unique(lim_sample)))

#satukan lungs dan infeksi jadi 3
lim_sample[lim_sample==2] = 1
lim_sample[lim_sample==3] = 2 
print('merged mask value: {}'.format(np.unique(lim_sample)))

#to categorical
lim_sample = to_categorical(lim_sample, num_classes = 3)
print('shape of the image  : {}'.format(np.shape(lim_sample)))
# Out:
# original mask value : [0. 1. 2. 3.]
# converted mask value: [0 1 2 3]
# merged mask value: [0 1 2]
# shape of the image  : (128, 128, 128, 3)

# %%
sample_slice = random.randint(0, ctimg_sample.shape[2])

plt.figure(figsize=(24, 8))

plt.subplot(231)
plt.imshow(ctimg_sample[:,:,sample_slice], cmap='bone')
plt.title('CT Images')
plt.subplot(232)
plt.imshow(lim_sample[:,:,sample_slice])
plt.title('lim')
plt.show()

# %%
ct_list = glob.glob('/content/data tidied/*/CT*')
lim_list = glob.glob('/content/data tidied/*/LIM*')

ct_list = sorted_alphanumeric(ct_list)
lim_list = sorted_alphanumeric(lim_list)

print(len((ct_list)),len((lim_list)))
# Out:
# 20 20

# %%
os.makedirs('/content/inf ready/ctscan')
os.makedirs('/content/inf ready/lim')

# %%
for i in range(len(ct_list)):
  print('prep ct image and lim mask image number: ', i)

  scaler = MinMaxScaler()
  ct_img = nib.load(ct_list[i]).get_fdata()

  scaler = MinMaxScaler()
  ct_img2 = scaler.fit_transform(ct_img.reshape(-1, ct_img.shape[-1]))
  ct_img2 = applyClahe(ct_img2)
  ct_img = scaler.fit_transform(ct_img2.reshape(-1, ct_img2.shape[-1])).reshape(ct_img.shape)
  ct_img = ct_img[:,:,:,0]
  ct_img = np.stack((ct_img,)*3, axis = -1)


  lim_img = nib.load(lim_list[i]).get_fdata()
  lim_img = lim_img.astype(np.uint8)
  lim_img[lim_img==2] = 1
  lim_img[lim_img==3] = 2 
  lim_img = to_categorical(lim_img, num_classes = 3)

  np.save('/content/inf ready/ctscan/ctscan_'+str(i)+'.npy',ct_img)
  np.save('/content/inf ready/lim/lim_'+str(i)+'.npy',lim_img)
# Out:
# prep ct image and lim mask image number:  0
# prep ct image and lim mask image number:  1
# prep ct image and lim mask image number:  2
# prep ct image and lim mask image number:  3
# prep ct image and lim mask image number:  4
# prep ct image and lim mask image number:  5
# prep ct image and lim mask image number:  6
# prep ct image and lim mask image number:  7
# prep ct image and lim mask image number:  8
# prep ct image and lim mask image number:  9
# prep ct image and lim mask image number:  10
# prep ct image and lim mask image number:  11
# prep ct image and lim mask image number:  12
# prep ct image and lim mask image number:  13
# prep ct image and lim mask image number:  14
# prep ct image and lim mask image number:  15
# prep ct image and lim mask image number:  16
# prep ct image and lim mask image number:  17
# prep ct image and lim mask image number:  18
# prep ct image and lim mask image number:  19

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
input_file = '/content/inf ready/'
output_file = '/content/drive/MyDrive/3D Segmentation/splitted 75 lim 128 data/'

# %%
splitfolders.ratio(input_file, output=output_file, seed=83, ratio=(.75, .25), group_prefix=None)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 2 files [00:00, 10.90 files/s]
# Copying files: 4 files [00:00,  7.03 files/s]
# Copying files: 5 files [00:00,  6.31 files/s]
# Copying files: 6 files [00:00,  5.62 files/s]
# Copying files: 7 files [00:01,  5.44 files/s]
# Copying files: 8 files [00:01,  5.42 files/s]
# Copying files: 9 files [00:01,  5.17 files/s]
# Copying files: 10 files [00:01,  5.21 files/s]
# Copying files: 11 files [00:01,  5.04 files/s]
# Copying files: 12 files [00:02,  4.85 files/s]
# Copying files: 13 files [00:03,  1.74 files/s]
# Copying files: 14 files [00:03,  2.14 files/s]
# Copying files: 15 files [00:04,  2.62 files/s]
# Copying files: 16 files [00:04,  3.08 files/s]
# Copying files: 17 files [00:04,  3.57 files/s]
# Copying files: 18 files [00:04,  3.95 files/s]
# Copying files: 19 files [00:04,  3.96 files/s]
# Copying files: 20 files [00:05,  4.05 files/s]
# Copying files: 21 files [00:05,  4.34 files/s]
# Copying files: 22 files [00:05,  5.09 files/s]
# Copying files: 23 files [00:05,  5.77 files/s]
# Copying files: 24 files [00:05,  6.57 files/s]
# Copying files: 25 files [00:05,  7.13 files/s]
# Copying files: 26 files [00:05,  7.46 files/s]
# Copying files: 27 files [00:05,  8.05 files/s]
# Copying files: 28 files [00:06,  8.50 files/s]
# Copying files: 29 files [00:06,  8.60 files/s]
# Copying files: 30 files [00:06,  8.26 files/s]
# Copying files: 31 files [00:07,  2.10 files/s]
# Copying files: 32 files [00:07,  2.73 files/s]
# Copying files: 33 files [00:07,  3.45 files/s]
# Copying files: 34 files [00:07,  4.18 files/s]
# Copying files: 35 files [00:08,  4.91 files/s]
# Copying files: 36 files [00:08,  5.74 files/s]
# Copying files: 37 files [00:08,  6.55 files/s]
# Copying files: 39 files [00:08,  7.76 files/s]
# Copying files: 40 files [00:08,  4.61 files/s]

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from keras.metrics import MeanIoU
from keras.preprocessing.image import ImageDataGenerator

# %%
pip install segmentation-models-3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation-models-3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-3D) (2.8.2+zzzcolab20220527125636)
# Collecting classification-models-3D>=1.0.6
#   Downloading classification_models_3D-1.0.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.8 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation-models-3D) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation-models-3D) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (3.3.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.46.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.5.3)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.26.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (57.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (3.17.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation-models-3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation-models-3D) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.2.0)
# Installing collected packages: keras-applications, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.6 keras-applications-1.0.8 segmentation-models-3D-1.0.4

# %%
import segmentation_models_3D as sm
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
kernel_initializer =  'he_uniform'

# %%
BACKBONE = 'vgg19'

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
import random
import tifffile as tiff
from tifffile import imread

def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name).astype(np.float32)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)

  
def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):
  
  length = len(img_list)

  while True:
    batch_start = 0
    batch_end = batch_size

    while batch_start < length:
      limit = min(batch_end, length)
      X = load_img(img_dir, img_list[batch_start:limit])
      Y = load_img(mask_dir, mask_list[batch_start:limit])

      yield(X, Y)

      batch_start += batch_size
      batch_end += batch_size

# %%
import os
import numpy as np
import keras
import tifffile as tiff
from tifffile import imread
import matplotlib.pyplot as plt
import glob
import random

# %%
train_img_dir = "/content/drive/MyDrive/3D Segmentation/splitted 75 lim 128 data/train/ctscan/"
train_mask_dir = "/content/drive/MyDrive/3D Segmentation/splitted 75 lim 128 data/train/lim/"

val_img_dir = "/content/drive/MyDrive/3D Segmentation/splitted 75 lim 128 data/val/ctscan/"
val_mask_dir = "/content/drive/MyDrive/3D Segmentation/splitted 75 lim 128 data/val/lim/"

train_img_list= sorted_alphanumeric(os.listdir(train_img_dir))
train_mask_list = sorted_alphanumeric(os.listdir(train_mask_dir))

val_img_list= sorted_alphanumeric(os.listdir(val_img_dir))
val_mask_list = sorted_alphanumeric(os.listdir(val_mask_dir))

# %%
batch_size = 1

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)


val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

# %%
img, msk = train_img_datagen.__next__()

# %%
print(img.shape)
print(msk.shape)
# Out:
# (1, 128, 128, 128, 3)
# (1, 128, 128, 128, 3)

# %%
img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]

n_slice=  random.randint(0, test_mask.shape[2])
print(n_slice) #70
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice,0], cmap='gray')
plt.title('ct')
plt.subplot(222)
plt.imshow(test_mask[:,:,n_slice])
plt.title('lim')
plt.show()
# Out:
# 121

# %%
dice_loss = sm.losses.DiceLoss() 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)
metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(), sm.losses.DiceLoss(), sm.losses.CategoricalFocalLoss(), sm.losses.JaccardLoss()]
LR = 0.0001
optim = tf.keras.optimizers.Adam(LR)
callbacks = [EarlyStopping(monitor='val_loss', patience=250, verbose=1)]

# %%
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# %%
model = sm.Unet(
                BACKBONE, 
                encoder_weights='imagenet',
                classes = 3,
                activation = 'softmax',
                input_shape = (128,128,128,3))
# Out:
# Downloading data from https://github.com/ZFTurbo/classification_models_3D/releases/download/v1.0.4/vgg19_inp_channel_3_tch_0_top_False.h5
# 240328704/240321880 [==============================] - 7s 0us/step
# 240336896/240321880 [==============================] - 7s 0us/step

# %%
model.compile(optimizer = optim, loss=total_loss, metrics=metrics)

# %%
history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=10000,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          callbacks = callbacks
          )
# Out:
# Epoch 1/10000
# 15/15 [==============================] - 52s 2s/step - loss: 0.7068 - iou_score: 0.3037 - f1-score: 0.3200 - dice_loss: 0.6800 - focal_loss: 0.0268 - jaccard_loss: 0.7783 - val_loss: 1.0071 - val_iou_score: 0.1444 - val_f1-score: 0.2487 - val_dice_loss: 0.7513 - val_focal_loss: 0.2558 - val_jaccard_loss: 0.8419
# Epoch 2/10000
# 15/15 [==============================] - 24s 2s/step - loss: 0
10000
# 15/15 [==============================] - 24s 2s/step - loss: 0.0407 - iou_score: 0.9471 - f1-score: 0.9603 - dice_loss: 0.0397 - focal_loss: 0.0010 - jaccard_loss: 0.0560 - val_loss: 0.1667 - val_iou_score: 0.7691 - val_f1-score: 0.8427 - val_dice_loss: 0.1573 - val_focal_loss: 0.0094 - val_jaccard_loss: 0.2338
# Epoch 848/10000
# 15/15 [==============================] - 24s 2s/step - loss: 0.0402 - iou_score: 0.9480 - f1-score: 0.9608 - dice_loss: 0.0392 - focal_loss: 9.8748e-04 - jaccard_loss: 0.0551 - val_loss: 0.1745 - val_iou_score: 0.7617 - val_f1-score: 0.8353 - val_dice_loss: 0.1647 - val_focal_loss: 0.0098 - val_jaccard_loss: 0.2412
# Epoch 849/10000
# 15/15 [==============================] - 24s 2s/step - loss: 0.0402 - iou_score: 0.9480 - f1-score: 0.9608 - dice_loss: 0.0392 - focal_loss: 0.0010 - jaccard_loss: 0.0551 - val_loss: 0.1756 - val_iou_score: 0.7588 - val_f1-score: 0.8347 - val_dice_loss: 0.1653 - val_focal_loss: 0.0103 - val_jaccard_loss: 0.2438
# Epoch 850/10000
# 15/15 [==============================] - 24s 2s/step - loss: 0.0395 - iou_score: 0.9493 - f1-score: 0.9615 - dice_loss: 0.0385 - focal_loss: 9.2688e-04 - jaccard_loss: 0.0538 - val_loss: 0.1705 - val_iou_score: 0.7650 - val_f1-score: 0.8390 - val_dice_loss: 0.1610 - val_focal_loss: 0.0095 - val_jaccard_loss: 0.2373
# Epoch 850: early stopping

# %%
model.save('/content/drive/MyDrive/3D Segmentation/vgg19unetlim75_tf.h5')

# %%
a =history.history['loss']
print(len(a))
#epoch
# Out:
# 850

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['dice_loss']
val_loss = history.history['val_dice_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training dice loss')
plt.plot(epochs, val_loss, 'r', label='Validation dice loss')
plt.title('Training and validation dice loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['focal_loss']
val_loss = history.history['val_focal_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training focal loss')
plt.plot(epochs, val_loss, 'r', label='Validation focal loss')
plt.title('Training and validation focal loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['jaccard_loss']
val_loss = history.history['val_jaccard_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training jaccard loss')
plt.plot(epochs, val_loss, 'r', label='Validation jaccard loss')
plt.title('Training and validation jaccard loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['iou_score']
val_acc = history.history['val_iou_score']
plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU Score')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
acc = history.history['f1-score']
val_acc = history.history['val_f1-score']
plt.plot(epochs, acc, 'y', label='Training F1')
plt.plot(epochs, val_acc, 'r', label='Validation F1')
plt.title('Training and validation F1score')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %%
imgtest, msktest = val_img_datagen.__next__()

# %%
model.evaluate(imgtest,msktest)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.2354 - iou_score: 0.6903 - f1-score: 0.7812 - dice_loss: 0.2188 - focal_loss: 0.0167 - jaccard_loss: 0.3106
# [0.23544299602508545,
#  0.690305769443512,
#  0.7812290787696838,
#  0.21877092123031616,
#  0.016672072932124138,
#  0.31057947874069214]
